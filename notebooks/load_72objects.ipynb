# %%
from visionlab.datasets import StreamingDataset

# %%
StreamingDataset?

# %%
s3_path = "s3://visionlab-datasets/exploring-objects-images"
dataset = StreamingDataset(s3_path, decode_images=True, to_pil=True)
dataset

# %%
sample = dataset[0]
sample.keys()

# %%
sample['image']

# %%
sample['filename']
